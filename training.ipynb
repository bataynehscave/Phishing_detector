# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
training = pd.read_csv('data/data_with_len.csv')

# %%
training.head()
# Out:
#                                                  url  label  https  len_url  \
# 0                        https://blog.sockpuppet.us/      0   True       27
# 1                  https://blog.apiki.com/seguranca/      0   True       33
# 2  http://autoecole-lauriston.com/a/T0RVd056QXlNe...      1  False       58
# 3  http://chinpay.site/index.html?hgcFSE@E$Z*DFcG...      1  False       74
# 4  http://www.firstfivenebraska.org/blog/article/...      0  False       80
#
#    have_host_name  have_ip  special_chars  digits  letters  letters_to_digits  \
# 0               1        0              3       0       21          22.000000
# 1               1        0              3       0       26          27.000000
# 2               1        0              5       6       42           6.142857
# 3               1        0              7       0       64          65.000000
# 4               1        0              8       2       65          22.000000
#
#    netloc_length  char_to_len
# ...

# %%
X_train = training.drop(['url','label', ], axis = 1)
y_train = training['label']

# %%
testing = pd.read_csv('data/test_data_with_len.csv')

# %%
testing.head()
# Out:
#                                                  url  label  https  len_url  \
# 0                       http://minsotc.alania.gov.ru      0  False       28
# 1                       http://www.freejavaguide.com      0  False       28
# 2  http://yeneliswa.co.za/moods/bankofamerica/7dd...      1  False      180
# 3  https://victordahdalehfoundation.com/programme...      0   True       68
# 4          http://camphhsi.com/product/list_947.html      0  False       41
#
#    have_host_name  have_ip  special_chars  digits  letters  letters_to_digits  \
# 0               1        0              4       0       22          23.000000
# 1               1        0              3       0       23          24.000000
# 2               1        0              9      50      112           2.215686
# 3               1        0              4       0       59          60.000000
# 4               1        0              3       3       30           7.750000
#
#    netloc_length  char_to_len
# ...

# %%
testing_x = testing.drop(['label', 'url'], axis=1)
testing_y = testing['label']

# %%
from sklearn.model_selection import train_test_split
X_val, X_test, y_val, y_test = train_test_split(testing_x, testing_y, test_size=0.5)

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.ensemble import BaggingClassifier

nb = CategoricalNB(alpha=0.4)
gbc = BaggingClassifier(n_jobs=-1)

# %%
nb.fit(X_train, y_train)
# Out:
# CategoricalNB(alpha=0.4)

# %%
gbc.fit(X_train, y_train)
# Out:
# BaggingClassifier(n_jobs=-1)

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(gbc, X_train, y_train, scoring='accuracy', cv=3)
# Out:
# array([0.81496742, 0.81380403, 0.81512124])

# %%
from sklearn.metrics import classification_report

# %%
nb_train_pred = nb.predict(X_train)

print(classification_report(nb_train_pred, y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74    374991
#            1       0.63      0.76      0.69    264997
#
#     accuracy                           0.72    639988
#    macro avg       0.72      0.72      0.72    639988
# weighted avg       0.73      0.72      0.72    639988

# %%
gbc_train_pred = gbc.predict(X_train)

print(classification_report(gbc_train_pred, y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90    348336
#            1       0.85      0.93      0.89    291652
#
#     accuracy                           0.89    639988
#    macro avg       0.89      0.90      0.89    639988
# weighted avg       0.90      0.89      0.89    639988

# %%
gbc_val_pred = gbc.predict(testing_x)

print(classification_report(gbc_val_pred, testing_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83     87153
#            1       0.78      0.85      0.81     72843
#
#     accuracy                           0.82    159996
#    macro avg       0.82      0.82      0.82    159996
# weighted avg       0.82      0.82      0.82    159996

# %%
from pipeline import predict_url

# %% [markdown]
# Example from outside the data

# %%
predict_url('https://www.bing.com/search?q=wasup&form=ANSPH1&refig=9306c22a78484452afa4e7aafd012f05&pc=U531', gbc)
# Out:
# 'safe'

# %%
predict_url('http://secure-login.paypa1l.com/verify_account', gbc)
# Out:
# 'PHISHING'

# %%
import joblib
joblib.dump(gbc, 'bagging_classifier.pkl')
# Out:
# ['bagging_classifier.pkl']

# %%
joblib.load('bagging_classifier.pkl')
# Out:
# BaggingClassifier(n_jobs=-1)
